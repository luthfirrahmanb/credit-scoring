# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv('./cs-training.csv')
df.head()
# Out:
#    Unnamed: 0  SeriousDlqin2yrs  RevolvingUtilizationOfUnsecuredLines  age  \
# 0           1                 1                              0.766127   45
# 1           2                 0                              0.957151   40
# 2           3                 0                              0.658180   38
# 3           4                 0                              0.233810   30
# 4           5                 0                              0.907239   49
#
#    NumberOfTime30-59DaysPastDueNotWorse  DebtRatio  MonthlyIncome  \
# 0                                     2   0.802982         9120.0
# 1                                     0   0.121876         2600.0
# 2                                     1   0.085113         3042.0
# 3                                     0   0.036050         3300.0
# 4                                     1   0.024926        63588.0
#
#    NumberOfOpenCreditLinesAndLoans  NumberOfTimes90DaysLate  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150000 entries, 0 to 149999
# Data columns (total 12 columns):
# Unnamed: 0                              150000 non-null int64
# SeriousDlqin2yrs                        150000 non-null int64
# RevolvingUtilizationOfUnsecuredLines    150000 non-null float64
# age                                     150000 non-null int64
# NumberOfTime30-59DaysPastDueNotWorse    150000 non-null int64
# DebtRatio                               150000 non-null float64
# MonthlyIncome                           120269 non-null float64
# NumberOfOpenCreditLinesAndLoans         150000 non-null int64
# NumberOfTimes90DaysLate                 150000 non-null int64
# NumberRealEstateLoansOrLines            150000 non-null int64
# NumberOfTime60-89DaysPastDueNotWorse    150000 non-null int64
# NumberOfDependents                      146076 non-null float64
# dtypes: float64(4), int64(8)
# memory usage: 13.7 MB

# %%
df.dropna(inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 120269 entries, 0 to 149999
# Data columns (total 12 columns):
# Unnamed: 0                              120269 non-null int64
# SeriousDlqin2yrs                        120269 non-null int64
# RevolvingUtilizationOfUnsecuredLines    120269 non-null float64
# age                                     120269 non-null int64
# NumberOfTime30-59DaysPastDueNotWorse    120269 non-null int64
# DebtRatio                               120269 non-null float64
# MonthlyIncome                           120269 non-null float64
# NumberOfOpenCreditLinesAndLoans         120269 non-null int64
# NumberOfTimes90DaysLate                 120269 non-null int64
# NumberRealEstateLoansOrLines            120269 non-null int64
# NumberOfTime60-89DaysPastDueNotWorse    120269 non-null int64
# NumberOfDependents                      120269 non-null float64
# dtypes: float64(4), int64(8)
# memory usage: 11.9 MB

# %%
df.drop('Unnamed: 0', axis=1, inplace=True)
df.head()
# Out:
#    SeriousDlqin2yrs  RevolvingUtilizationOfUnsecuredLines  age  \
# 0                 1                              0.766127   45
# 1                 0                              0.957151   40
# 2                 0                              0.658180   38
# 3                 0                              0.233810   30
# 4                 0                              0.907239   49
#
#    NumberOfTime30-59DaysPastDueNotWorse  DebtRatio  MonthlyIncome  \
# 0                                     2   0.802982         9120.0
# 1                                     0   0.121876         2600.0
# 2                                     1   0.085113         3042.0
# 3                                     0   0.036050         3300.0
# 4                                     1   0.024926        63588.0
#
#    NumberOfOpenCreditLinesAndLoans  NumberOfTimes90DaysLate  \
# 0                               13                        0
# 1                                4                        0
# ...

# %%
df.describe()
# Out:
#        SeriousDlqin2yrs  RevolvingUtilizationOfUnsecuredLines            age  \
# count     120269.000000                         120269.000000  120269.000000
# mean           0.069486                              5.899873      51.289792
# std            0.254280                            257.040685      14.426684
# min            0.000000                              0.000000       0.000000
# 25%            0.000000                              0.035084      40.000000
# 50%            0.000000                              0.177282      51.000000
# 75%            0.000000                              0.579428      61.000000
# max            1.000000                          50708.000000     103.000000
#
#        NumberOfTime30-59DaysPastDueNotWorse      DebtRatio  MonthlyIncome  \
# count                         120269.000000  120269.000000   1.202690e+05
# mean                               0.381769      26.598777   6.670221e+03
# ...

# %%
df = df[(df['age'] > 0)]
df.describe()
# Out:
#        SeriousDlqin2yrs  RevolvingUtilizationOfUnsecuredLines            age  \
# count     120268.000000                         120268.000000  120268.000000
# mean           0.069486                              5.899913      51.290219
# std            0.254281                            257.041753      14.425986
# min            0.000000                              0.000000      21.000000
# 25%            0.000000                              0.035083      40.000000
# 50%            0.000000                              0.177280      51.000000
# 75%            0.000000                              0.579428      61.000000
# max            1.000000                          50708.000000     103.000000
#
#        NumberOfTime30-59DaysPastDueNotWorse      DebtRatio  MonthlyIncome  \
# count                         120268.000000  120268.000000   1.202680e+05
# mean                               0.381764      26.598995   6.670227e+03
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 120268 entries, 0 to 149999
# Data columns (total 11 columns):
# SeriousDlqin2yrs                        120268 non-null int64
# RevolvingUtilizationOfUnsecuredLines    120268 non-null float64
# age                                     120268 non-null int64
# NumberOfTime30-59DaysPastDueNotWorse    120268 non-null int64
# DebtRatio                               120268 non-null float64
# MonthlyIncome                           120268 non-null float64
# NumberOfOpenCreditLinesAndLoans         120268 non-null int64
# NumberOfTimes90DaysLate                 120268 non-null int64
# NumberRealEstateLoansOrLines            120268 non-null int64
# NumberOfTime60-89DaysPastDueNotWorse    120268 non-null int64
# NumberOfDependents                      120268 non-null float64
# dtypes: float64(4), int64(7)
# memory usage: 11.0 MB

# %%
plt.figure(figsize = (16,16))
sns.heatmap(df.corr(), annot=True)

# %%
plt.figure(figsize = (30,20))
df.groupby('age')['SeriousDlqin2yrs'].value_counts().plot(kind = 'bar')

# %%
plt.figure(figsize = (30,20))
sns.scatterplot(data=df, x='age', y='NumberOfOpenCreditLinesAndLoans', hue='SeriousDlqin2yrs')

# %%
type2AscMean = df.groupby('age')['MonthlyIncome'].mean().sort_values(ascending=False).index
fig, ax = plt.subplots(figsize=(20,10))
sns.barplot(data=df, x='age', y='MonthlyIncome', order=type2AscMean, estimator=np.mean).set_title('Age & Monthly Income Mean Bar Plot')
# Out:
# Text(0.5,1,'Age & Monthly Income Mean Bar Plot')

# %%
df.groupby('NumberOfDependents')['DebtRatio'].mean().plot(kind = 'bar')

# %%
df.groupby('NumberOfDependents')['RevolvingUtilizationOfUnsecuredLines'].mean().plot(kind = 'bar')

# %%
plt.figure(figsize = (30,20))
df.groupby('NumberOfOpenCreditLinesAndLoans')['DebtRatio'].mean().plot(kind = 'bar')

# %%
plt.figure(figsize = (30,20))
df.groupby('age')['DebtRatio'].mean().plot(kind = 'bar')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 120268 entries, 0 to 149999
# Data columns (total 11 columns):
# SeriousDlqin2yrs                        120268 non-null int64
# RevolvingUtilizationOfUnsecuredLines    120268 non-null float64
# age                                     120268 non-null int64
# NumberOfTime30-59DaysPastDueNotWorse    120268 non-null int64
# DebtRatio                               120268 non-null float64
# MonthlyIncome                           120268 non-null float64
# NumberOfOpenCreditLinesAndLoans         120268 non-null int64
# NumberOfTimes90DaysLate                 120268 non-null int64
# NumberRealEstateLoansOrLines            120268 non-null int64
# NumberOfTime60-89DaysPastDueNotWorse    120268 non-null int64
# NumberOfDependents                      120268 non-null float64
# dtypes: float64(4), int64(7)
# memory usage: 16.0 MB

# %%
# df.drop(['SeriousDlqin2yrs', 'age'], axis=1)
from sklearn.model_selection import train_test_split, cross_val_score
data = df.drop(['SeriousDlqin2yrs'], axis=1)
target = df['SeriousDlqin2yrs']

X_train, X_test, y_train, y_test = train_test_split(data, target, test_size=0.30, random_state=101)

# %%
X_train.head()
# Out:
#         RevolvingUtilizationOfUnsecuredLines  age  \
# 99501                               0.100578   36
# 93405                               0.634640   55
# 134116                              1.000000   81
# 40649                               0.046355   60
# 120283                              0.110481   62
#
#         NumberOfTime30-59DaysPastDueNotWorse  DebtRatio  MonthlyIncome  \
# 99501                                      0   0.087064         4467.0
# 93405                                      0   0.249496        10416.0
# 134116                                     0   0.116057         6806.0
# 40649                                      1   0.230252        11000.0
# 120283                                     0   0.340416         6776.0
#
#         NumberOfOpenCreditLinesAndLoans  NumberOfTimes90DaysLate  \
# 99501                                 8                        0
# 93405                                14                        0
# ...

# %%
y_train.head()
# Out:
# 99501     0
# 93405     0
# 134116    0
# 40649     0
# 120283    0
# Name: SeriousDlqin2yrs, dtype: int64

# %%
pd.Series(y_train).value_counts()
# Out:
# 0    78359
# 1     5828
# Name: SeriousDlqin2yrs, dtype: int64

# %%
from sklearn.metrics import classification_report, roc_auc_score, confusion_matrix, matthews_corrcoef

from xgboost import XGBClassifier
from imblearn.over_sampling import RandomOverSampler
xgb = XGBClassifier(random_state=101,n_estimators=100,learning_rate=0.1)
ros = RandomOverSampler(random_state=101)

X_ros, y_ros = ros.fit_sample(X_train, y_train)

# %%
pd.Series(y_ros).value_counts()
# Out:
# 1    78359
# 0    78359
# dtype: int64

# %%
rocAuc = cross_val_score(xgb,X_ros,y_ros, scoring = 'roc_auc', cv=5)
print('AUC Score for this model : ' , rocAuc)
# Out:
# AUC Score for this model :  [0.86239808 0.85940907 0.86134416 0.86294476 0.86273198]

# %%
xgb.fit(X_ros, y_ros)
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=1, gamma=0, learning_rate=0.1, max_delta_step=0,
#        max_depth=3, min_child_weight=1, missing=None, n_estimators=100,
#        n_jobs=1, nthread=None, objective='binary:logistic',
#        random_state=101, reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#        seed=None, silent=True, subsample=1)

# %%
predict = xgb.predict(X_ros)
predictProb = xgb.predict_proba(X_ros)
# Out:
# C:\Users\Luthfir\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:

# %%
print(confusion_matrix(y_ros,predict))
print(classification_report(y_ros, predict))
print("Roc Auc Score: {}".format(roc_auc_score(y_ros, predictProb[:,1])))
print("Matthew: {}".format(matthews_corrcoef(y_ros, predict)))
# Out:
# [[62086 16273]
#  [17876 60483]]
#              precision    recall  f1-score   support
#
#           0       0.78      0.79      0.78     78359
#           1       0.79      0.77      0.78     78359
#
# avg / total       0.78      0.78      0.78    156718
#
# Roc Auc Score: 0.8628504353536319
# Matthew: 0.5643162076502787

# %%
predictProb[:,1]
# Out:
# array([0.17381042, 0.45617086, 0.29452828, ..., 0.863437  , 0.15034308,
#        0.57337564], dtype=float32)
